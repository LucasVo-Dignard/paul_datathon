# %%
from requests import post, get

response = post("http://127.0.0.1:5000/upload", files={"bill": open("""6.人工知能関連技術の研究開発及び活用の推進に関する法律.html""", "rb")})

# %%
response.content
# Out:
# b'{\n  "text": "good"\n}\n'

# %%
bad : 0
good : 7
